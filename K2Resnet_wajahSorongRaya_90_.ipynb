# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Sift-Features/blob/main/K2Resnet_wajahSorongRaya_90_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB5
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/wajahPBD"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/WajahSorongRaya2"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: Maybrat, Image Count: 350
# Folder: Raja Ampat, Image Count: 337
# Folder: SorongSelatan, Image Count: 339
# Folder: Moi, Image Count: 364

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(haar_image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 889
# Jumlah data validasi: 223
# Jumlah data test: 278

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
"""
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB5(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
"""
# Out:
# "\n# Define CNN model with pretrained ResNet50\ndef build_model():\n    input_tensor = Input(shape=(224, 224, 3))\n    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)\n    #base_model = EfficientNetB5(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB\n    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)\n    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))\n    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))\n    x = base_model.output\n    x = GlobalAveragePooling2D()(x)\n    x = BatchNormalization()(x)\n    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan\n    x = Dropout(0.5)(x)\n    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)\n    x = Dropout(0.5)(x)\n    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)\n    #x = Dropout(0.5)(x)\n    predictions = Dense(len(encoder.classes_), activation='softmax')(x)\n\n    model = Model(inputs=base_model.input, outputs=predictions)\n\n    # Unfreeze the top layers of the model\n    for layer in base_model.layers[-50:]:\n        layer.trainable = True\n\n    # Compile model\n    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])\n    return model\n\nmodel = build_model()\n"

# %%
def build_model():
    input_tensor = Input(shape=(224, 224, 3))

    # Tetap menggunakan ResNet50
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)

    # Freezing layer awal
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)

    # Tambahkan lapisan dense dengan regularisasi lebih kompleks
    x = Dense(512, activation='relu',
              kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.001, l2=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.6)(x)

    x = Dense(256, activation='relu',
              kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.001, l2=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Output layer
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze lapisan terakhir untuk fine-tuning
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Gunakan learning rate yang dapat disesuaikan
    optimizer = tf.keras.optimizers.Adam(
        learning_rate=tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=1e-4,
            decay_steps=100,
            decay_rate=0.9
        )
    )

    # Tambahkan metrik tambahan untuk evaluasi
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy',
                 tf.keras.metrics.Precision(),
                 tf.keras.metrics.Recall()]
    )

    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Data augmentation
#train_datagen = ImageDataGenerator(
#    rotation_range=30,
#    width_shift_range=0.3,
#    height_shift_range=0.3,
#    shear_range=0.3,
#    zoom_range=0.3,
#    horizontal_flip=True,
#    brightness_range=[0.7, 1.3],
#    fill_mode='nearest'
#)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

train_datagen = ImageDataGenerator(
    rotation_range=40,  # Sedikit naikkan rentang rotasi
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=False,  # Hindari flip vertikal untuk wajah
    brightness_range=[0.6, 1.4],  # Perluas rentang kecerahan
    fill_mode='nearest'
)

# %%
# Fungsi tambahan untuk noise
def random_noise(image):
    return tf.keras.preprocessing.image.random_noise(image, mode='gaussian', seed=None)

# %%
# Untuk menambahkan kontras, Anda bisa menggunakan fungsi preprocessing
def adjust_contrast(image):
    return tf.image.adjust_contrast(image, contrast_factor=tf.random.uniform([], 0.7, 1.3))

# %%
# Kemudian gunakan sebagai preprocessing_function
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=False,
    brightness_range=[0.6, 1.4],
    fill_mode='nearest',
    preprocessing_function=adjust_contrast
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)


# Print the number of samples in each set
#print("Jumlah data train:", len(train_images))
#print("Jumlah data validasi:", len(val_images))
#print("Jumlah data test:", len(test_images))

# %%
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1112
# Jumlah data validasi: 223
# Jumlah data test: 278

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.3388 - loss: 44.7424 - precision: 0.3638 - recall: 0.3001 - val_accuracy: 0.7194 - val_loss: 43.0783 - val_precision: 0.8364 - val_recall: 0.6619 - learning_rate: 9.6380e-05
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 516ms/step - accuracy: 0.7052 - loss: 42.9309 - precision: 0.7276 - recall: 0.6613 - val_accuracy: 0.7626 - val_loss: 42.1787 - val_precision: 0.8132 - val_recall: 0.7518 - learning_rate: 9.2890e-05
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 517ms/step - accuracy: 0.7689 - loss: 42.0516 - precision: 0.7874 - recall: 0.7456 - val_accuracy: 0.8237 - val_loss: 41.3291 - val_precision: 0.8352 - val_recall: 0.8022 - learning_rate: 8.9527e-05
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 515ms/step - accuracy: 0.8261 - loss: 41.1980 - precision: 0.8439 - recall: 0.8067 - val_accuracy: 0.8921 - val_loss: 40.5233 - val_precision: 0.8930 - val_recall: 0.8705 - learning_rate: 8.6286e-05
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 519ms/step - accuracy: 0.8567 - loss: 40.3882 - precision: 0.8753 - recall: 0.8471 - val_accuracy: 0.9137 - val_loss: 39.6786 - val_precision: 0.9236 - val_recall: 0.9137 - learning_rate: 8.3162e-05
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.8822 - loss: 39.6047 - precision: 0.8901 - recall: 0.8716 - val_accuracy: 0.9245 - val_loss: 38.9170 - val_precision: 0.9275 - val_recall: 0.9209 - learning_rate: 8.0151e-05
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 19s 553ms/step - accuracy: 0.8853 - loss: 38.8367 - precision: 0.8965 - recall: 0.8757 - val_accuracy: 0.9317 - val_loss: 38.1448 - val_precision: 0.9314 - val_recall: 0.9281 - learning_rate: 7.7249e-05
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.8984 - loss: 38.0447 - precision: 0.9043 - recall: 0.8862 - val_accuracy: 0.9388 - val_loss: 37.3780 - val_precision: 0.9386 - val_recall: 0.9353 - learning_rate: 7.4452e-05
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.8937 - loss: 37.2972 - precision: 0.9075 - recall: 0.8870 - val_accuracy: 0.9281 - val_loss: 36.6222 - val_precision: 0.9348 - val_recall: 0.9281 - learning_rate: 7.1757e-05
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.8824 - loss: 36.5464 - precision: 0.9022 - recall: 0.8718 - val_accuracy: 0.9065 - val_loss: 35.9597 - val_precision: 0.9094 - val_recall: 0.9029 - learning_rate: 6.9159e-05
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9172 - loss: 35.7806 - precision: 0.9214 - recall: 0.9112 - val_accuracy: 0.9532 - val_loss: 35.1488 - val_precision: 0.9532 - val_recall: 0.9532 - learning_rate: 6.6655e-05
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9139 - loss: 35.0675 - precision: 0.9214 - recall: 0.9068 - val_accuracy: 0.9137 - val_loss: 34.5465 - val_precision: 0.9167 - val_recall: 0.9101 - learning_rate: 6.4242e-05
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 519ms/step - accuracy: 0.9028 - loss: 34.4078 - precision: 0.9145 - recall: 0.8999 - val_accuracy: 0.9353 - val_loss: 33.8064 - val_precision: 0.9386 - val_recall: 0.9353 - learning_rate: 6.1916e-05
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 527ms/step - accuracy: 0.9253 - loss: 33.6794 - precision: 0.9335 - recall: 0.9226 - val_accuracy: 0.9353 - val_loss: 33.1563 - val_precision: 0.9418 - val_recall: 0.9317 - learning_rate: 5.9674e-05
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9089 - loss: 33.0818 - precision: 0.9148 - recall: 0.9005 - val_accuracy: 0.9532 - val_loss: 32.4743 - val_precision: 0.9567 - val_recall: 0.9532 - learning_rate: 5.7514e-05
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9059 - loss: 32.4820 - precision: 0.9137 - recall: 0.9049 - val_accuracy: 0.9568 - val_loss: 31.8619 - val_precision: 0.9565 - val_recall: 0.9496 - learning_rate: 5.5432e-05
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 526ms/step - accuracy: 0.9343 - loss: 31.7756 - precision: 0.9390 - recall: 0.9310 - val_accuracy: 0.9353 - val_loss: 31.3248 - val_precision: 0.9420 - val_recall: 0.9353 - learning_rate: 5.3425e-05
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 518ms/step - accuracy: 0.9200 - loss: 31.2071 - precision: 0.9254 - recall: 0.9160 - val_accuracy: 0.9496 - val_loss: 30.7160 - val_precision: 0.9493 - val_recall: 0.9424 - learning_rate: 5.1491e-05
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9310 - loss: 30.6160 - precision: 0.9338 - recall: 0.9271 - val_accuracy: 0.9604 - val_loss: 30.1332 - val_precision: 0.9603 - val_recall: 0.9568 - learning_rate: 4.9626e-05
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 516ms/step - accuracy: 0.9217 - loss: 30.0618 - precision: 0.9274 - recall: 0.9151 - val_accuracy: 0.9496 - val_loss: 29.6035 - val_precision: 0.9564 - val_recall: 0.9460 - learning_rate: 4.7830e-05
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9215 - loss: 29.5243 - precision: 0.9275 - recall: 0.9212 - val_accuracy: 0.9532 - val_loss: 29.0665 - val_precision: 0.9601 - val_recall: 0.9532 - learning_rate: 4.6098e-05
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9281 - loss: 29.0149 - precision: 0.9342 - recall: 0.9268 - val_accuracy: 0.9604 - val_loss: 28.5571 - val_precision: 0.9639 - val_recall: 0.9604 - learning_rate: 4.4429e-05
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9503 - loss: 28.4324 - precision: 0.9569 - recall: 0.9460 - val_accuracy: 0.9532 - val_loss: 28.0671 - val_precision: 0.9532 - val_recall: 0.9532 - learning_rate: 4.2821e-05
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 526ms/step - accuracy: 0.9343 - loss: 27.9974 - precision: 0.9379 - recall: 0.9298 - val_accuracy: 0.9496 - val_loss: 27.6081 - val_precision: 0.9529 - val_recall: 0.9460 - learning_rate: 4.1270e-05
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 519ms/step - accuracy: 0.9449 - loss: 27.4939 - precision: 0.9516 - recall: 0.9408 - val_accuracy: 0.9604 - val_loss: 27.1347 - val_precision: 0.9639 - val_recall: 0.9604 - learning_rate: 3.9776e-05
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9494 - loss: 27.0638 - precision: 0.9501 - recall: 0.9462 - val_accuracy: 0.9317 - val_loss: 26.7542 - val_precision: 0.9350 - val_recall: 0.9317 - learning_rate: 3.8336e-05
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9518 - loss: 26.5644 - precision: 0.9669 - recall: 0.9500 - val_accuracy: 0.9245 - val_loss: 26.3485 - val_precision: 0.9278 - val_recall: 0.9245 - learning_rate: 3.6948e-05
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9497 - loss: 26.1887 - precision: 0.9520 - recall: 0.9469 - val_accuracy: 0.9353 - val_loss: 25.9244 - val_precision: 0.9384 - val_recall: 0.9317 - learning_rate: 3.5610e-05
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9399 - loss: 25.7839 - precision: 0.9426 - recall: 0.9337 - val_accuracy: 0.9604 - val_loss: 25.4528 - val_precision: 0.9603 - val_recall: 0.9568 - learning_rate: 3.4321e-05
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 19s 529ms/step - accuracy: 0.9611 - loss: 25.3652 - precision: 0.9649 - recall: 0.9502 - val_accuracy: 0.9604 - val_loss: 25.0872 - val_precision: 0.9638 - val_recall: 0.9568 - learning_rate: 3.3079e-05
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9415 - loss: 25.0565 - precision: 0.9454 - recall: 0.9329 - val_accuracy: 0.9496 - val_loss: 24.7517 - val_precision: 0.9529 - val_recall: 0.9460 - learning_rate: 3.1881e-05
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9686 - loss: 24.5935 - precision: 0.9691 - recall: 0.9676 - val_accuracy: 0.9604 - val_loss: 24.3711 - val_precision: 0.9638 - val_recall: 0.9568 - learning_rate: 3.0727e-05
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 527ms/step - accuracy: 0.9532 - loss: 24.3202 - precision: 0.9551 - recall: 0.9528 - val_accuracy: 0.9460 - val_loss: 24.0465 - val_precision: 0.9527 - val_recall: 0.9424 - learning_rate: 2.9614e-05
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9472 - loss: 23.9291 - precision: 0.9536 - recall: 0.9419 - val_accuracy: 0.9640 - val_loss: 23.7127 - val_precision: 0.9638 - val_recall: 0.9568 - learning_rate: 2.8542e-05
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 532ms/step - accuracy: 0.9629 - loss: 23.5882 - precision: 0.9676 - recall: 0.9544 - val_accuracy: 0.9532 - val_loss: 23.4045 - val_precision: 0.9565 - val_recall: 0.9496 - learning_rate: 2.7509e-05
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 19s 538ms/step - accuracy: 0.9557 - loss: 23.2799 - precision: 0.9624 - recall: 0.9545 - val_accuracy: 0.9532 - val_loss: 23.1012 - val_precision: 0.9531 - val_recall: 0.9496 - learning_rate: 2.6513e-05
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9634 - loss: 22.9773 - precision: 0.9663 - recall: 0.9619 - val_accuracy: 0.9460 - val_loss: 22.8149 - val_precision: 0.9495 - val_recall: 0.9460 - learning_rate: 2.5553e-05
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9444 - loss: 22.7134 - precision: 0.9469 - recall: 0.9401 - val_accuracy: 0.9353 - val_loss: 22.5582 - val_precision: 0.9418 - val_recall: 0.9317 - learning_rate: 2.4628e-05
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9481 - loss: 22.4235 - precision: 0.9532 - recall: 0.9449 - val_accuracy: 0.9388 - val_loss: 22.2785 - val_precision: 0.9386 - val_recall: 0.9353 - learning_rate: 2.3736e-05
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9498 - loss: 22.1501 - precision: 0.9548 - recall: 0.9468 - val_accuracy: 0.9604 - val_loss: 21.9616 - val_precision: 0.9604 - val_recall: 0.9604 - learning_rate: 2.2877e-05
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 519ms/step - accuracy: 0.9556 - loss: 21.9194 - precision: 0.9603 - recall: 0.9546 - val_accuracy: 0.9532 - val_loss: 21.7308 - val_precision: 0.9565 - val_recall: 0.9496 - learning_rate: 2.2049e-05
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9463 - loss: 21.6748 - precision: 0.9529 - recall: 0.9460 - val_accuracy: 0.9532 - val_loss: 21.4871 - val_precision: 0.9567 - val_recall: 0.9532 - learning_rate: 2.1250e-05
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9612 - loss: 21.3940 - precision: 0.9689 - recall: 0.9590 - val_accuracy: 0.9388 - val_loss: 21.2782 - val_precision: 0.9422 - val_recall: 0.9388 - learning_rate: 2.0481e-05
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9669 - loss: 21.1378 - precision: 0.9720 - recall: 0.9637 - val_accuracy: 0.9496 - val_loss: 21.0375 - val_precision: 0.9496 - val_recall: 0.9496 - learning_rate: 1.9739e-05
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9648 - loss: 20.9159 - precision: 0.9732 - recall: 0.9623 - val_accuracy: 0.9532 - val_loss: 20.8022 - val_precision: 0.9600 - val_recall: 0.9496 - learning_rate: 1.9025e-05
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 519ms/step - accuracy: 0.9684 - loss: 20.7271 - precision: 0.9704 - recall: 0.9681 - val_accuracy: 0.9604 - val_loss: 20.6047 - val_precision: 0.9603 - val_recall: 0.9568 - learning_rate: 1.8336e-05
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9603 - loss: 20.5329 - precision: 0.9632 - recall: 0.9603 - val_accuracy: 0.9532 - val_loss: 20.3987 - val_precision: 0.9600 - val_recall: 0.9496 - learning_rate: 1.7672e-05
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9597 - loss: 20.3016 - precision: 0.9627 - recall: 0.9563 - val_accuracy: 0.9460 - val_loss: 20.2315 - val_precision: 0.9495 - val_recall: 0.9460 - learning_rate: 1.7032e-05
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9764 - loss: 20.0878 - precision: 0.9781 - recall: 0.9736 - val_accuracy: 0.9496 - val_loss: 20.0487 - val_precision: 0.9531 - val_recall: 0.9496 - learning_rate: 1.6416e-05
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9613 - loss: 19.9523 - precision: 0.9661 - recall: 0.9601 - val_accuracy: 0.9388 - val_loss: 19.9429 - val_precision: 0.9388 - val_recall: 0.9388 - learning_rate: 1.5821e-05
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9652 - loss: 19.7603 - precision: 0.9678 - recall: 0.9620 - val_accuracy: 0.9209 - val_loss: 19.7826 - val_precision: 0.9275 - val_recall: 0.9209 - learning_rate: 1.5249e-05
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9662 - loss: 19.5751 - precision: 0.9677 - recall: 0.9633 - val_accuracy: 0.9424 - val_loss: 19.5743 - val_precision: 0.9493 - val_recall: 0.9424 - learning_rate: 1.4696e-05
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9760 - loss: 19.3903 - precision: 0.9793 - recall: 0.9752 - val_accuracy: 0.9281 - val_loss: 19.4362 - val_precision: 0.9314 - val_recall: 0.9281 - learning_rate: 1.4164e-05
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9589 - loss: 19.2393 - precision: 0.9604 - recall: 0.9565 - val_accuracy: 0.9424 - val_loss: 19.2543 - val_precision: 0.9424 - val_recall: 0.9424 - learning_rate: 1.3652e-05
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9558 - loss: 19.1234 - precision: 0.9567 - recall: 0.9554 - val_accuracy: 0.9209 - val_loss: 19.1417 - val_precision: 0.9275 - val_recall: 0.9209 - learning_rate: 1.3157e-05
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9784 - loss: 18.9167 - precision: 0.9807 - recall: 0.9732 - val_accuracy: 0.9353 - val_loss: 18.9681 - val_precision: 0.9350 - val_recall: 0.9317 - learning_rate: 1.2681e-05
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9686 - loss: 18.7888 - precision: 0.9713 - recall: 0.9672 - val_accuracy: 0.9353 - val_loss: 18.7965 - val_precision: 0.9386 - val_recall: 0.9353 - learning_rate: 1.2222e-05
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9626 - loss: 18.6804 - precision: 0.9639 - recall: 0.9569 - val_accuracy: 0.9460 - val_loss: 18.6370 - val_precision: 0.9495 - val_recall: 0.9460 - learning_rate: 1.1779e-05
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9653 - loss: 18.5228 - precision: 0.9690 - recall: 0.9612 - val_accuracy: 0.9388 - val_loss: 18.5511 - val_precision: 0.9388 - val_recall: 0.9388 - learning_rate: 1.1353e-05
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9766 - loss: 18.3996 - precision: 0.9769 - recall: 0.9736 - val_accuracy: 0.9317 - val_loss: 18.4325 - val_precision: 0.9317 - val_recall: 0.9317 - learning_rate: 1.0942e-05
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 519ms/step - accuracy: 0.9652 - loss: 18.2689 - precision: 0.9683 - recall: 0.9652 - val_accuracy: 0.9353 - val_loss: 18.3081 - val_precision: 0.9353 - val_recall: 0.9353 - learning_rate: 1.0546e-05
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9822 - loss: 18.1421 - precision: 0.9823 - recall: 0.9809 - val_accuracy: 0.9353 - val_loss: 18.1760 - val_precision: 0.9386 - val_recall: 0.9353 - learning_rate: 1.0164e-05
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9712 - loss: 18.0521 - precision: 0.9730 - recall: 0.9694 - val_accuracy: 0.9388 - val_loss: 18.0494 - val_precision: 0.9457 - val_recall: 0.9388 - learning_rate: 9.7960e-06
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9656 - loss: 17.9245 - precision: 0.9699 - recall: 0.9646 - val_accuracy: 0.9424 - val_loss: 17.9445 - val_precision: 0.9493 - val_recall: 0.9424 - learning_rate: 9.4413e-06
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9667 - loss: 17.8253 - precision: 0.9738 - recall: 0.9653 - val_accuracy: 0.9460 - val_loss: 17.8293 - val_precision: 0.9460 - val_recall: 0.9460 - learning_rate: 9.0995e-06
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9786 - loss: 17.7055 - precision: 0.9806 - recall: 0.9785 - val_accuracy: 0.9424 - val_loss: 17.7358 - val_precision: 0.9458 - val_recall: 0.9424 - learning_rate: 8.7700e-06
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9610 - loss: 17.6212 - precision: 0.9658 - recall: 0.9597 - val_accuracy: 0.9317 - val_loss: 17.6706 - val_precision: 0.9317 - val_recall: 0.9317 - learning_rate: 8.4525e-06
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9646 - loss: 17.5095 - precision: 0.9654 - recall: 0.9645 - val_accuracy: 0.9245 - val_loss: 17.5993 - val_precision: 0.9278 - val_recall: 0.9245 - learning_rate: 8.1465e-06
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9660 - loss: 17.4462 - precision: 0.9659 - recall: 0.9623 - val_accuracy: 0.9281 - val_loss: 17.4985 - val_precision: 0.9348 - val_recall: 0.9281 - learning_rate: 7.8516e-06
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9794 - loss: 17.3297 - precision: 0.9841 - recall: 0.9794 - val_accuracy: 0.9317 - val_loss: 17.4151 - val_precision: 0.9350 - val_recall: 0.9317 - learning_rate: 7.5673e-06
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9759 - loss: 17.2521 - precision: 0.9759 - recall: 0.9733 - val_accuracy: 0.9424 - val_loss: 17.3062 - val_precision: 0.9458 - val_recall: 0.9424 - learning_rate: 7.2933e-06
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9764 - loss: 17.1663 - precision: 0.9799 - recall: 0.9711 - val_accuracy: 0.9353 - val_loss: 17.2370 - val_precision: 0.9353 - val_recall: 0.9353 - learning_rate: 7.0293e-06
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 529ms/step - accuracy: 0.9712 - loss: 17.0924 - precision: 0.9748 - recall: 0.9710 - val_accuracy: 0.9388 - val_loss: 17.1522 - val_precision: 0.9422 - val_recall: 0.9388 - learning_rate: 6.7748e-06
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9801 - loss: 17.0018 - precision: 0.9813 - recall: 0.9797 - val_accuracy: 0.9353 - val_loss: 17.0828 - val_precision: 0.9386 - val_recall: 0.9353 - learning_rate: 6.5295e-06
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9642 - loss: 16.9394 - precision: 0.9649 - recall: 0.9606 - val_accuracy: 0.9388 - val_loss: 17.0012 - val_precision: 0.9422 - val_recall: 0.9388 - learning_rate: 6.2931e-06
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 518ms/step - accuracy: 0.9827 - loss: 16.8584 - precision: 0.9830 - recall: 0.9818 - val_accuracy: 0.9424 - val_loss: 16.9254 - val_precision: 0.9458 - val_recall: 0.9424 - learning_rate: 6.0653e-06
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9754 - loss: 16.8349 - precision: 0.9755 - recall: 0.9721 - val_accuracy: 0.9388 - val_loss: 16.8630 - val_precision: 0.9422 - val_recall: 0.9388 - learning_rate: 5.8457e-06
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9726 - loss: 16.7418 - precision: 0.9733 - recall: 0.9697 - val_accuracy: 0.9460 - val_loss: 16.7864 - val_precision: 0.9529 - val_recall: 0.9460 - learning_rate: 5.6340e-06
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9701 - loss: 16.6718 - precision: 0.9742 - recall: 0.9665 - val_accuracy: 0.9532 - val_loss: 16.7092 - val_precision: 0.9532 - val_recall: 0.9532 - learning_rate: 5.4301e-06
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9768 - loss: 16.5967 - precision: 0.9807 - recall: 0.9768 - val_accuracy: 0.9532 - val_loss: 16.6503 - val_precision: 0.9532 - val_recall: 0.9532 - learning_rate: 5.2335e-06
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 527ms/step - accuracy: 0.9706 - loss: 16.5493 - precision: 0.9732 - recall: 0.9660 - val_accuracy: 0.9532 - val_loss: 16.5950 - val_precision: 0.9567 - val_recall: 0.9532 - learning_rate: 5.0440e-06
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 19s 529ms/step - accuracy: 0.9654 - loss: 16.5041 - precision: 0.9656 - recall: 0.9640 - val_accuracy: 0.9640 - val_loss: 16.5371 - val_precision: 0.9672 - val_recall: 0.9532 - learning_rate: 4.8614e-06
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 19s 532ms/step - accuracy: 0.9828 - loss: 16.4211 - precision: 0.9839 - recall: 0.9819 - val_accuracy: 0.9532 - val_loss: 16.4883 - val_precision: 0.9601 - val_recall: 0.9532 - learning_rate: 4.6854e-06
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 527ms/step - accuracy: 0.9742 - loss: 16.3914 - precision: 0.9789 - recall: 0.9692 - val_accuracy: 0.9568 - val_loss: 16.4346 - val_precision: 0.9638 - val_recall: 0.9568 - learning_rate: 4.5157e-06
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9916 - loss: 16.2999 - precision: 0.9931 - recall: 0.9895 - val_accuracy: 0.9568 - val_loss: 16.3803 - val_precision: 0.9638 - val_recall: 0.9568 - learning_rate: 4.3523e-06
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 525ms/step - accuracy: 0.9724 - loss: 16.2842 - precision: 0.9728 - recall: 0.9706 - val_accuracy: 0.9568 - val_loss: 16.3387 - val_precision: 0.9603 - val_recall: 0.9568 - learning_rate: 4.1947e-06
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9791 - loss: 16.2291 - precision: 0.9823 - recall: 0.9762 - val_accuracy: 0.9568 - val_loss: 16.2918 - val_precision: 0.9601 - val_recall: 0.9532 - learning_rate: 4.0428e-06
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9662 - loss: 16.1935 - precision: 0.9708 - recall: 0.9657 - val_accuracy: 0.9640 - val_loss: 16.2330 - val_precision: 0.9639 - val_recall: 0.9604 - learning_rate: 3.8964e-06
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9798 - loss: 16.1403 - precision: 0.9808 - recall: 0.9798 - val_accuracy: 0.9640 - val_loss: 16.1905 - val_precision: 0.9639 - val_recall: 0.9604 - learning_rate: 3.7554e-06
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9841 - loss: 16.0919 - precision: 0.9849 - recall: 0.9839 - val_accuracy: 0.9640 - val_loss: 16.1454 - val_precision: 0.9674 - val_recall: 0.9604 - learning_rate: 3.6194e-06
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9660 - loss: 16.0955 - precision: 0.9672 - recall: 0.9625 - val_accuracy: 0.9604 - val_loss: 16.1074 - val_precision: 0.9604 - val_recall: 0.9604 - learning_rate: 3.4884e-06
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 517ms/step - accuracy: 0.9794 - loss: 16.0087 - precision: 0.9848 - recall: 0.9742 - val_accuracy: 0.9604 - val_loss: 16.0691 - val_precision: 0.9674 - val_recall: 0.9604 - learning_rate: 3.3621e-06
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9912 - loss: 15.9599 - precision: 0.9915 - recall: 0.9843 - val_accuracy: 0.9568 - val_loss: 16.0361 - val_precision: 0.9568 - val_recall: 0.9568 - learning_rate: 3.2404e-06
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 522ms/step - accuracy: 0.9816 - loss: 15.9353 - precision: 0.9827 - recall: 0.9805 - val_accuracy: 0.9568 - val_loss: 16.0032 - val_precision: 0.9565 - val_recall: 0.9496 - learning_rate: 3.1230e-06
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 19s 530ms/step - accuracy: 0.9861 - loss: 15.8957 - precision: 0.9867 - recall: 0.9852 - val_accuracy: 0.9532 - val_loss: 15.9733 - val_precision: 0.9565 - val_recall: 0.9496 - learning_rate: 3.0100e-06
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 523ms/step - accuracy: 0.9794 - loss: 15.8746 - precision: 0.9802 - recall: 0.9774 - val_accuracy: 0.9496 - val_loss: 15.9462 - val_precision: 0.9527 - val_recall: 0.9424 - learning_rate: 2.9010e-06
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9857 - loss: 15.8226 - precision: 0.9866 - recall: 0.9843 - val_accuracy: 0.9460 - val_loss: 15.9164 - val_precision: 0.9493 - val_recall: 0.9424 - learning_rate: 2.7960e-06
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 524ms/step - accuracy: 0.9813 - loss: 15.7982 - precision: 0.9818 - recall: 0.9773 - val_accuracy: 0.9460 - val_loss: 15.8909 - val_precision: 0.9460 - val_recall: 0.9460 - learning_rate: 2.6947e-06
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 528ms/step - accuracy: 0.9707 - loss: 15.7806 - precision: 0.9754 - recall: 0.9695 - val_accuracy: 0.9460 - val_loss: 15.8726 - val_precision: 0.9460 - val_recall: 0.9460 - learning_rate: 2.5972e-06
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 520ms/step - accuracy: 0.9758 - loss: 15.7506 - precision: 0.9769 - recall: 0.9734 - val_accuracy: 0.9424 - val_loss: 15.8438 - val_precision: 0.9424 - val_recall: 0.9424 - learning_rate: 2.5032e-06

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 564ms/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.98      0.86      0.92        70
#           Moi       0.89      0.95      0.92        76
#    Raja Ampat       0.94      1.00      0.97        64
# SorongSelatan       0.97      0.97      0.97        68
#
#      accuracy                           0.94       278
#     macro avg       0.95      0.94      0.94       278
#  weighted avg       0.94      0.94      0.94       278
