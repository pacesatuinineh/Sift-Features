# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Sift-Features/blob/main/K1EfficientNet_wajahSorongRaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB5
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/wajahPBD"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/WajahSorongRaya"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: SorongSelatan, Image Count: 320
# Folder: Moi2, Image Count: 364
# Folder: Raja Ampat, Image Count: 337
# Folder: Maybrat, Image Count: 355

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    #haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    #haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 880
# Jumlah data validasi: 220
# Jumlah data test: 276

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    #base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    base_model = EfficientNetB5(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)


# Print the number of samples in each set
#print("Jumlah data train:", len(train_images))
#print("Jumlah data validasi:", len(val_images))
#print("Jumlah data test:", len(test_images))

# %%
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1100
# Jumlah data validasi: 220
# Jumlah data test: 276

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 283s 3s/step - accuracy: 0.2662 - loss: 13.6646 - val_accuracy: 0.4928 - val_loss: 12.7285 - learning_rate: 1.0000e-04
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.4895 - loss: 12.7698 - val_accuracy: 0.5036 - val_loss: 12.4533 - learning_rate: 1.0000e-04
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 19s 526ms/step - accuracy: 0.5699 - loss: 12.4058 - val_accuracy: 0.5507 - val_loss: 12.1648 - learning_rate: 1.0000e-04
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 509ms/step - accuracy: 0.6485 - loss: 11.9872 - val_accuracy: 0.6051 - val_loss: 11.9066 - learning_rate: 1.0000e-04
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 495ms/step - accuracy: 0.6969 - loss: 11.7626 - val_accuracy: 0.6232 - val_loss: 11.6610 - learning_rate: 1.0000e-04
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 496ms/step - accuracy: 0.7121 - loss: 11.4632 - val_accuracy: 0.6957 - val_loss: 11.3802 - learning_rate: 1.0000e-04
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.7285 - loss: 11.3160 - val_accuracy: 0.7210 - val_loss: 11.1686 - learning_rate: 1.0000e-04
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 511ms/step - accuracy: 0.7139 - loss: 11.1663 - val_accuracy: 0.7609 - val_loss: 10.9657 - learning_rate: 1.0000e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 506ms/step - accuracy: 0.7447 - loss: 10.8845 - val_accuracy: 0.7572 - val_loss: 10.7718 - learning_rate: 1.0000e-04
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 499ms/step - accuracy: 0.7837 - loss: 10.6250 - val_accuracy: 0.7790 - val_loss: 10.5981 - learning_rate: 1.0000e-04
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.7584 - loss: 10.4937 - val_accuracy: 0.7862 - val_loss: 10.3848 - learning_rate: 1.0000e-04
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.7641 - loss: 10.2684 - val_accuracy: 0.7681 - val_loss: 10.1436 - learning_rate: 1.0000e-04
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.8126 - loss: 10.0052 - val_accuracy: 0.8152 - val_loss: 9.8945 - learning_rate: 1.0000e-04
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.7819 - loss: 9.8654 - val_accuracy: 0.7899 - val_loss: 9.6881 - learning_rate: 1.0000e-04
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.8277 - loss: 9.6261 - val_accuracy: 0.8152 - val_loss: 9.4840 - learning_rate: 1.0000e-04
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.8417 - loss: 9.4134 - val_accuracy: 0.8152 - val_loss: 9.3192 - learning_rate: 1.0000e-04
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.7989 - loss: 9.2467 - val_accuracy: 0.8442 - val_loss: 9.1162 - learning_rate: 1.0000e-04
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.8656 - loss: 8.9755 - val_accuracy: 0.8152 - val_loss: 8.9704 - learning_rate: 1.0000e-04
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.8598 - loss: 8.7943 - val_accuracy: 0.8225 - val_loss: 8.7649 - learning_rate: 1.0000e-04
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.8693 - loss: 8.6118 - val_accuracy: 0.8188 - val_loss: 8.5698 - learning_rate: 1.0000e-04
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.8588 - loss: 8.4524 - val_accuracy: 0.8188 - val_loss: 8.3717 - learning_rate: 1.0000e-04
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.8891 - loss: 8.1500 - val_accuracy: 0.8297 - val_loss: 8.1811 - learning_rate: 1.0000e-04
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9015 - loss: 7.9832 - val_accuracy: 0.8225 - val_loss: 8.0173 - learning_rate: 1.0000e-04
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9082 - loss: 7.7845 - val_accuracy: 0.8225 - val_loss: 7.8420 - learning_rate: 1.0000e-04
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 502ms/step - accuracy: 0.8941 - loss: 7.5864 - val_accuracy: 0.8225 - val_loss: 7.6404 - learning_rate: 1.0000e-04
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9050 - loss: 7.3807 - val_accuracy: 0.8080 - val_loss: 7.4840 - learning_rate: 1.0000e-04
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.8975 - loss: 7.2136 - val_accuracy: 0.8007 - val_loss: 7.3378 - learning_rate: 1.0000e-04
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 506ms/step - accuracy: 0.9236 - loss: 6.9887 - val_accuracy: 0.8080 - val_loss: 7.1592 - learning_rate: 1.0000e-04
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 506ms/step - accuracy: 0.9157 - loss: 6.8108 - val_accuracy: 0.8152 - val_loss: 6.9594 - learning_rate: 1.0000e-04
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 495ms/step - accuracy: 0.9075 - loss: 6.6444 - val_accuracy: 0.8225 - val_loss: 6.8099 - learning_rate: 1.0000e-04
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9249 - loss: 6.4752 - val_accuracy: 0.8116 - val_loss: 6.6336 - learning_rate: 1.0000e-04
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 505ms/step - accuracy: 0.9163 - loss: 6.2967 - val_accuracy: 0.8225 - val_loss: 6.4356 - learning_rate: 1.0000e-04
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9242 - loss: 6.1069 - val_accuracy: 0.8370 - val_loss: 6.2394 - learning_rate: 1.0000e-04
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 496ms/step - accuracy: 0.9399 - loss: 5.8965 - val_accuracy: 0.8116 - val_loss: 6.1746 - learning_rate: 1.0000e-04
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 499ms/step - accuracy: 0.9428 - loss: 5.7175 - val_accuracy: 0.8261 - val_loss: 5.9634 - learning_rate: 1.0000e-04
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9292 - loss: 5.5687 - val_accuracy: 0.8152 - val_loss: 5.7948 - learning_rate: 1.0000e-04
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 505ms/step - accuracy: 0.9505 - loss: 5.3679 - val_accuracy: 0.8188 - val_loss: 5.7139 - learning_rate: 1.0000e-04
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 506ms/step - accuracy: 0.9360 - loss: 5.2413 - val_accuracy: 0.8514 - val_loss: 5.4746 - learning_rate: 1.0000e-04
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 500ms/step - accuracy: 0.9553 - loss: 5.0390 - val_accuracy: 0.7790 - val_loss: 5.3825 - learning_rate: 1.0000e-04
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 497ms/step - accuracy: 0.9392 - loss: 4.9086 - val_accuracy: 0.8043 - val_loss: 5.2384 - learning_rate: 1.0000e-04
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9676 - loss: 4.7206 - val_accuracy: 0.8188 - val_loss: 5.1547 - learning_rate: 1.0000e-04
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 500ms/step - accuracy: 0.9357 - loss: 4.6098 - val_accuracy: 0.8261 - val_loss: 4.9203 - learning_rate: 1.0000e-04
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 505ms/step - accuracy: 0.9562 - loss: 4.4387 - val_accuracy: 0.8080 - val_loss: 4.7867 - learning_rate: 1.0000e-04
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9560 - loss: 4.2903 - val_accuracy: 0.8261 - val_loss: 4.5932 - learning_rate: 1.0000e-04
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 502ms/step - accuracy: 0.9697 - loss: 4.1153 - val_accuracy: 0.8225 - val_loss: 4.4566 - learning_rate: 1.0000e-04
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9597 - loss: 3.9975 - val_accuracy: 0.8116 - val_loss: 4.4448 - learning_rate: 1.0000e-04
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 500ms/step - accuracy: 0.9663 - loss: 3.8550 - val_accuracy: 0.8043 - val_loss: 4.3333 - learning_rate: 1.0000e-04
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9578 - loss: 3.7215 - val_accuracy: 0.8116 - val_loss: 4.1048 - learning_rate: 1.0000e-04
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9644 - loss: 3.5941 - val_accuracy: 0.8225 - val_loss: 3.9427 - learning_rate: 1.0000e-04
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 508ms/step - accuracy: 0.9610 - loss: 3.4620 - val_accuracy: 0.8406 - val_loss: 3.8464 - learning_rate: 1.0000e-04
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.9730 - loss: 3.3239 - val_accuracy: 0.8261 - val_loss: 3.7424 - learning_rate: 1.0000e-04
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 17s 489ms/step - accuracy: 0.9795 - loss: 3.1760 - val_accuracy: 0.8116 - val_loss: 3.7568 - learning_rate: 1.0000e-04
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9804 - loss: 3.0594 - val_accuracy: 0.8080 - val_loss: 3.6293 - learning_rate: 1.0000e-04
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9735 - loss: 2.9698 - val_accuracy: 0.8152 - val_loss: 3.4566 - learning_rate: 1.0000e-04
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 505ms/step - accuracy: 0.9519 - loss: 2.8964 - val_accuracy: 0.8261 - val_loss: 3.3522 - learning_rate: 1.0000e-04
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 502ms/step - accuracy: 0.9776 - loss: 2.7346 - val_accuracy: 0.8225 - val_loss: 3.2858 - learning_rate: 1.0000e-04
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 499ms/step - accuracy: 0.9774 - loss: 2.6310 - val_accuracy: 0.8152 - val_loss: 3.1005 - learning_rate: 1.0000e-04
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 499ms/step - accuracy: 0.9624 - loss: 2.5239 - val_accuracy: 0.8261 - val_loss: 2.9988 - learning_rate: 1.0000e-04
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 495ms/step - accuracy: 0.9710 - loss: 2.4485 - val_accuracy: 0.8188 - val_loss: 3.0409 - learning_rate: 1.0000e-04
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9812 - loss: 2.3230 - val_accuracy: 0.8551 - val_loss: 2.7616 - learning_rate: 1.0000e-04
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 502ms/step - accuracy: 0.9785 - loss: 2.2233 - val_accuracy: 0.8297 - val_loss: 2.6900 - learning_rate: 1.0000e-04
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 502ms/step - accuracy: 0.9798 - loss: 2.1398 - val_accuracy: 0.8297 - val_loss: 2.6803 - learning_rate: 1.0000e-04
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 502ms/step - accuracy: 0.9813 - loss: 2.0464 - val_accuracy: 0.8804 - val_loss: 2.4976 - learning_rate: 1.0000e-04
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9793 - loss: 1.9619 - val_accuracy: 0.8297 - val_loss: 2.5505 - learning_rate: 1.0000e-04
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 498ms/step - accuracy: 0.9899 - loss: 1.8648 - val_accuracy: 0.8514 - val_loss: 2.4527 - learning_rate: 1.0000e-04
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 17s 490ms/step - accuracy: 0.9820 - loss: 1.7902 - val_accuracy: 0.8116 - val_loss: 2.6188 - learning_rate: 1.0000e-04
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9742 - loss: 1.7428 - val_accuracy: 0.8406 - val_loss: 2.2296 - learning_rate: 1.0000e-04
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 506ms/step - accuracy: 0.9828 - loss: 1.6439 - val_accuracy: 0.8406 - val_loss: 2.1404 - learning_rate: 1.0000e-04
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 507ms/step - accuracy: 0.9772 - loss: 1.5937 - val_accuracy: 0.8587 - val_loss: 2.1295 - learning_rate: 1.0000e-04
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9774 - loss: 1.5169 - val_accuracy: 0.8297 - val_loss: 2.0348 - learning_rate: 1.0000e-04
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9776 - loss: 1.4561 - val_accuracy: 0.8116 - val_loss: 2.0808 - learning_rate: 1.0000e-04
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.9815 - loss: 1.3809 - val_accuracy: 0.8514 - val_loss: 1.9066 - learning_rate: 1.0000e-04
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 503ms/step - accuracy: 0.9743 - loss: 1.3253 - val_accuracy: 0.8406 - val_loss: 1.8245 - learning_rate: 1.0000e-04
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 498ms/step - accuracy: 0.9813 - loss: 1.2661 - val_accuracy: 0.8623 - val_loss: 1.7067 - learning_rate: 1.0000e-04
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 492ms/step - accuracy: 0.9779 - loss: 1.2111 - val_accuracy: 0.8478 - val_loss: 1.7795 - learning_rate: 1.0000e-04
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 491ms/step - accuracy: 0.9886 - loss: 1.1346 - val_accuracy: 0.8297 - val_loss: 1.7686 - learning_rate: 1.0000e-04
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.9794 - loss: 1.1060 - val_accuracy: 0.8514 - val_loss: 1.6114 - learning_rate: 1.0000e-04
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9874 - loss: 1.0570 - val_accuracy: 0.8478 - val_loss: 1.6140 - learning_rate: 1.0000e-04
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 495ms/step - accuracy: 0.9864 - loss: 0.9880 - val_accuracy: 0.8551 - val_loss: 1.6387 - learning_rate: 1.0000e-04
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 500ms/step - accuracy: 0.9849 - loss: 0.9700 - val_accuracy: 0.8478 - val_loss: 1.4443 - learning_rate: 1.0000e-04
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 495ms/step - accuracy: 0.9864 - loss: 0.9082 - val_accuracy: 0.8587 - val_loss: 1.4958 - learning_rate: 1.0000e-04
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 496ms/step - accuracy: 0.9836 - loss: 0.8586 - val_accuracy: 0.8514 - val_loss: 1.5382 - learning_rate: 1.0000e-04
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9808 - loss: 0.8439 - val_accuracy: 0.8370 - val_loss: 1.5832 - learning_rate: 1.0000e-04
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 17s 489ms/step - accuracy: 0.9817 - loss: 0.7914 - val_accuracy: 0.8370 - val_loss: 1.4940 - learning_rate: 1.0000e-04
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.9797 - loss: 0.7638 - val_accuracy: 0.8442 - val_loss: 1.3807 - learning_rate: 1.0000e-04
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 500ms/step - accuracy: 0.9887 - loss: 0.7062 - val_accuracy: 0.8659 - val_loss: 1.2939 - learning_rate: 1.0000e-04
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 491ms/step - accuracy: 0.9865 - loss: 0.6798 - val_accuracy: 0.8478 - val_loss: 1.3097 - learning_rate: 1.0000e-04
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9849 - loss: 0.6593 - val_accuracy: 0.8116 - val_loss: 1.5283 - learning_rate: 1.0000e-04
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 514ms/step - accuracy: 0.9831 - loss: 0.6600 - val_accuracy: 0.8333 - val_loss: 1.1955 - learning_rate: 1.0000e-04
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 496ms/step - accuracy: 0.9863 - loss: 0.5956 - val_accuracy: 0.8261 - val_loss: 1.2137 - learning_rate: 1.0000e-04
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9917 - loss: 0.5485 - val_accuracy: 0.8297 - val_loss: 1.1997 - learning_rate: 1.0000e-04
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 491ms/step - accuracy: 0.9825 - loss: 0.5370 - val_accuracy: 0.8333 - val_loss: 1.1975 - learning_rate: 1.0000e-04
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 509ms/step - accuracy: 0.9903 - loss: 0.5057 - val_accuracy: 0.8333 - val_loss: 1.1372 - learning_rate: 1.0000e-04
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9907 - loss: 0.4754 - val_accuracy: 0.8333 - val_loss: 1.2379 - learning_rate: 1.0000e-04
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9890 - loss: 0.4648 - val_accuracy: 0.8406 - val_loss: 1.1720 - learning_rate: 1.0000e-04
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 496ms/step - accuracy: 0.9916 - loss: 0.4364 - val_accuracy: 0.8442 - val_loss: 1.1513 - learning_rate: 1.0000e-04
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 501ms/step - accuracy: 0.9898 - loss: 0.4174 - val_accuracy: 0.8406 - val_loss: 1.1165 - learning_rate: 1.0000e-04
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 492ms/step - accuracy: 0.9859 - loss: 0.4074 - val_accuracy: 0.8370 - val_loss: 1.1235 - learning_rate: 1.0000e-04
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 492ms/step - accuracy: 0.9867 - loss: 0.3897 - val_accuracy: 0.8297 - val_loss: 1.1543 - learning_rate: 1.0000e-04
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 502ms/step - accuracy: 0.9876 - loss: 0.3751 - val_accuracy: 0.8333 - val_loss: 1.0624 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.78      0.54      0.64        74
#          Moi2       0.99      0.99      0.99        77
#    Raja Ampat       0.98      0.98      0.98        64
# SorongSelatan       0.61      0.84      0.70        61
#
#      accuracy                           0.83       276
#     macro avg       0.84      0.84      0.83       276
#  weighted avg       0.85      0.83      0.83       276
