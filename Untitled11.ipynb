# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Sift-Features/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inisialisasi dan Setup**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install -U --pre efficientnet
from efficientnet.tfkeras import EfficientNetB1
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import seaborn as sns
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
import cv2
# Out:
# Mounted at /content/drive
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.5.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.0)
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %% [markdown]
# # **Memuat dan Memproses Data dengan SIFT Features**

# %%
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3

# path = "/content/drive/MyDrive/Split_data/suku9/train"
path = "/content/drive/MyDrive/suku12/train"
lists_dir = os.listdir(path)
categories = []
file_name = []
for folder in lists_dir:
    files = os.listdir(path + "/" + folder)
    for file in files:
        path_file = path + "/" + folder + "/" + file
        file_name.append(path_file)
        categories.append(folder)

df = {"image": file_name, "categories": categories}
data = pd.DataFrame(df, index=None)
data = data.sample(frac=1)
data.head(5)

# Precompute SIFT Features and save images
sift_images_path = '/content/sift_images/train/'
os.makedirs(sift_images_path, exist_ok=True)

def apply_sift_features(image):
    sift = cv2.SIFT_create()
    keypoints, descriptors = sift.detectAndCompute(image, None)
    return keypoints

sift_file_paths = []
for i, row in data.iterrows():
    img = cv2.imread(row['image'], cv2.IMREAD_GRAYSCALE)
    keypoints = apply_sift_features(img)
    img_sift = cv2.drawKeypoints(img, keypoints, img)
    new_path = os.path.join(sift_images_path, os.path.basename(row['image']))
    cv2.imwrite(new_path, img_sift)
    sift_file_paths.append(new_path)

data['sift_image'] = sift_file_paths

# path_datatest = "/content/drive/MyDrive/Split_data/suku9/test"
path_datatest = "/content/drive/MyDrive/suku12/test"
lists_dir_datatest = os.listdir(path_datatest)
categories_datatest = []
file_name_datatest = []
for folder in lists_dir_datatest:
    files = os.listdir(path_datatest + "/" + folder)
    for file in files:
        path_file = path_datatest + "/" + folder + "/" + file
        file_name_datatest.append(path_file)
        categories_datatest.append(folder)

df_datatest = {"image": file_name_datatest, "categories": categories_datatest}
data_datatest = pd.DataFrame(df_datatest, index=None)
data_datatest = data_datatest.sample(frac=1)
nb_samples = data_datatest.shape[0]
data_datatest

# Precompute SIFT Features and save images for test set
sift_images_test_path = '/content/sift_images/test/'
os.makedirs(sift_images_test_path, exist_ok=True)

sift_test_file_paths = []
for i, row in data_datatest.iterrows():
    img = cv2.imread(row['image'], cv2.IMREAD_GRAYSCALE)
    keypoints = apply_sift_features(img)
    img_sift = cv2.drawKeypoints(img, keypoints, img)
    new_path = os.path.join(sift_images_test_path, os.path.basename(row['image']))
    cv2.imwrite(new_path, img_sift)
    sift_test_file_paths.append(new_path)

data_datatest['sift_image'] = sift_test_file_paths

data['categories'].value_counts().plot.bar()

total_dataset = len(data_datatest) + len(data)
print("Total dataset Suku: {} Suku".format(total_dataset))

data["categories"] = data["categories"].replace({0: 'moi', 1: 'nonmoi'})

train_df, validate_df = train_test_split(data, test_size=0.10, random_state=20)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

train_df['categories'].value_counts().plot.bar()
validate_df['categories'].value_counts().plot.bar()
# Out:
# Total dataset Suku: 637 Suku
# <Axes: xlabel='categories'>

# %% [markdown]
# # **Mempersiapkan ImageDataGenerator tanpa SIFT Features**

# %%
batch_size = 64

train_datagen = ImageDataGenerator(
    rotation_range=30,
    rescale=1./255,
    shear_range=0.1,
    vertical_flip=True,
    zoom_range=0.2,
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=None,  # Specify directory as None because full paths are provided in 'sift_image'
    x_col='sift_image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)

validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=validate_df,
    directory=None,  # Specify directory as None because full paths are provided in 'sift_image'
    x_col='sift_image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 459 validated image filenames belonging to 2 classes.
# Found 52 validated image filenames belonging to 2 classes.

# %% [markdown]
# # **Visualisasi Data**

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    dataframe=example_df,
    directory=None,  # Specify directory as None because full paths are provided in 'sift_image'
    x_col='sift_image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)

plt.figure(figsize=(12, 12))
for i in range(0, 10):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %% [markdown]
# # **Membuat dan Melatih Model**

# %%
base_model = EfficientNetB1(input_shape=(224, 224, 3),
                            include_top=False,
                            weights='noisy-student')

for layer in base_model.layers:
    layer.trainable = False

model = Sequential()
model.add(base_model)
model.add(Conv2D(640, kernel_size=(1, 1)))
model.add(Flatten())
model.add(Dense(320, kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))

model.compile("adam", loss="binary_crossentropy", metrics=["accuracy"])
model.summary()

epochs = 30
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=1
)
# Out:
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b1_noisy-student_notop.h5
# 27010080/27010080 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnet-b1 (Functiona  (None, 7, 7, 1280)        6575232
#  l)
#
#  conv2d (Conv2D)             (None, 7, 7, 640)         819840
#
#  flatten (Flatten)           (None, 31360)             0
#
#  dense (Dense)               (None, 320)               10035520
#
#  batch_normalization (Batch  (None, 320)               1280
#  Normalization)
#
#  re_lu (ReLU)                (None, 320)               0
#
#  dropout (Dropout)           (None, 320)               0
#
#  dense_1 (Dense)             (None, 2)                 642
#
# =================================================================
# Total params: 17432514 (66.50 MB)
# Trainable params: 10856642 (41.41 MB)
# Non-trainable params: 6575872 (25.08 MB)
# _________________________________________________________________
# Epoch 1/30
# 8/8 [==============================] - 23s 1s/step - loss: 0.9224 - accuracy: 0.6383 - val_loss: 1.4419 - val_accuracy: 0.8077
# Epoch 2/30
# 8/8 [==============================] - 8s 937ms/step - loss: 0.4138 - accuracy: 0.8192 - val_loss: 2.3909 - val_accuracy: 0.7692
# Epoch 3/30
# 8/8 [==============================] - 8s 946ms/step - loss: 0.3308 - accuracy: 0.8693 - val_loss: 1.6682 - val_accuracy: 0.7692
# Epoch 4/30
# 8/8 [==============================] - 8s 936ms/step - loss: 0.2943 - accuracy: 0.8736 - val_loss: 0.6345 - val_accuracy: 0.8462
# Epoch 5/30
# 8/8 [==============================] - 8s 936ms/step - loss: 0.2644 - accuracy: 0.9172 - val_loss: 0.3883 - val_accuracy: 0.8846
# Epoch 6/30
# 8/8 [==============================] - 8s 929ms/step - loss: 0.2417 - accuracy: 0.8932 - val_loss: 0.2004 - val_accuracy: 0.9231
# Epoch 7/30
# 8/8 [==============================] - 8s 934ms/step - loss: 0.2357 - accuracy: 0.8954 - val_loss: 0.1606 - val_accuracy: 0.9423
# Epoch 8/30
# 8/8 [==============================] - 8s 946ms/step - loss: 0.2061 - accuracy: 0.9172 - val_loss: 0.1785 - val_accuracy: 0.9423
# Epoch 9/30
# 8/8 [==============================] - 8s 931ms/step - loss: 0.2003 - accuracy: 0.9237 - val_loss: 0.2213 - val_accuracy: 0.9038
# Epoch 10/30
# 8/8 [==============================] - 8s 902ms/step - loss: 0.1800 - accuracy: 0.9325 - val_loss: 0.0892 - val_accuracy: 0.9615
# Epoch 11/30
# 8/8 [==============================] - 8s 1s/step - loss: 0.2277 - accuracy: 0.9107 - val_loss: 0.2331 - val_accuracy: 0.9231
# Epoch 12/30
# 8/8 [==============================] - 8s 946ms/step - loss: 0.1996 - accuracy: 0.9237 - val_loss: 0.1984 - val_accuracy: 0.9615
# Epoch 13/30
# 8/8 [==============================] - 8s 933ms/step - loss: 0.1929 - accuracy: 0.9172 - val_loss: 0.2174 - val_accuracy: 0.9615
# Epoch 14/30
# 8/8 [==============================] - 8s 935ms/step - loss: 0.1530 - accuracy: 0.9368 - val_loss: 0.0992 - val_accuracy: 0.9423
# Epoch 15/30
# 8/8 [==============================] - 8s 912ms/step - loss: 0.1534 - accuracy: 0.9542 - val_loss: 0.1082 - val_accuracy: 0.9615
# Epoch 16/30
# 8/8 [==============================] - 8s 932ms/step - loss: 0.1669 - accuracy: 0.9412 - val_loss: 0.0523 - val_accuracy: 0.9808
# Epoch 17/30
# 8/8 [==============================] - 8s 1s/step - loss: 0.1292 - accuracy: 0.9499 - val_loss: 0.0458 - val_accuracy: 0.9808
# Epoch 18/30
# 8/8 [==============================] - 8s 935ms/step - loss: 0.1438 - accuracy: 0.9412 - val_loss: 0.0708 - val_accuracy: 0.9808
# Epoch 19/30
# 8/8 [==============================] - 8s 1s/step - loss: 0.1694 - accuracy: 0.9434 - val_loss: 0.1144 - val_accuracy: 0.9615
# Epoch 20/30
# 8/8 [==============================] - 8s 927ms/step - loss: 0.1079 - accuracy: 0.9651 - val_loss: 0.1405 - val_accuracy: 0.9615
# Epoch 21/30
# 8/8 [==============================] - 8s 914ms/step - loss: 0.1042 - accuracy: 0.9564 - val_loss: 0.0937 - val_accuracy: 0.9423
# Epoch 22/30
# 8/8 [==============================] - 8s 960ms/step - loss: 0.1122 - accuracy: 0.9521 - val_loss: 0.0796 - val_accuracy: 0.9615
# Epoch 23/30
# 8/8 [==============================] - 8s 938ms/step - loss: 0.1298 - accuracy: 0.9586 - val_loss: 0.0823 - val_accuracy: 0.9615
# Epoch 24/30
# 8/8 [==============================] - 8s 921ms/step - loss: 0.1224 - accuracy: 0.9542 - val_loss: 0.1051 - val_accuracy: 0.9423
# Epoch 25/30
# 8/8 [==============================] - 8s 925ms/step - loss: 0.1560 - accuracy: 0.9434 - val_loss: 0.0990 - val_accuracy: 0.9423
# Epoch 26/30
# 8/8 [==============================] - 7s 909ms/step - loss: 0.1192 - accuracy: 0.9564 - val_loss: 0.1940 - val_accuracy: 0.9038
# Epoch 27/30
# 8/8 [==============================] - 8s 1s/step - loss: 0.1655 - accuracy: 0.9368 - val_loss: 0.2562 - val_accuracy: 0.9231
# Epoch 28/30
# 8/8 [==============================] - 8s 932ms/step - loss: 0.1227 - accuracy: 0.9521 - val_loss: 0.1602 - val_accuracy: 0.9423
# Epoch 29/30
# 8/8 [==============================] - 8s 926ms/step - loss: 0.1260 - accuracy: 0.9455 - val_loss: 0.0915 - val_accuracy: 0.9423
# Epoch 30/30
# 8/8 [==============================] - 8s 930ms/step - loss: 0.0961 - accuracy: 0.9630 - val_loss: 0.1602 - val_accuracy: 0.9423

# %% [markdown]
# # **Evalusai Model**

# %%
plt.plot(history.history["accuracy"], label="Akurasi Pelatihan")
plt.plot(history.history["val_accuracy"], label="Validasi Akurasi")
plt.legend()
plt.show()

plt.plot(history.history["loss"], label="Kesalahan Pelatihan")
plt.plot(history.history["val_loss"], label="Validasi Kesalahan")
plt.legend()
plt.show()

test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    dataframe=data_datatest,
    directory=None,  # Specify directory as None because full paths are provided in 'sift_image'
    x_col='sift_image',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)

predict = model.predict(test_generator, steps=np.ceil(nb_samples / batch_size))

predicted_classes = np.argmax(predict, axis=1)
true_classes = np.array(data_datatest['categories'].replace(['moi', 'nonmoi'], [0, 1]))
class_labels = ['0', '1']

cm = confusion_matrix(true_classes, predicted_classes)
cm_df = pd.DataFrame(cm, index=['moi', 'nonmoi'], columns=['moi', 'nonmoi'])

plt.figure(figsize=(8, 8))
sns.heatmap(cm_df, annot=True)
plt.title('CNN EfficientNet-B1 \nAccuracy:{0:.3f}'.format(accuracy_score(true_classes, predicted_classes)))
plt.ylabel('Label Sebenarnya')
plt.xlabel('Label Prediksi')
plt.show()

report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)

model.save('geeksforgeeks.h5')
# Out:
# Found 126 validated image filenames.
# 2/2 [==============================] - 1s 489ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        90
#            1       1.00      0.33      0.50        36
#
#     accuracy                           0.81       126
#    macro avg       0.89      0.67      0.69       126
# weighted avg       0.85      0.81      0.77       126
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
