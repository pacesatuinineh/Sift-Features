# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Sift-Features/blob/main/K3EfficientNet_WajahSorongRaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3
# !pip install PyWavelets
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from PyWavelets) (1.26.4)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 38.9 MB/s eta 0:00:00
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB0
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np
import pywt

import random
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/modifdataset"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/WajahSorongRaya"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: SorongSelatan, Image Count: 320
# Folder: Moi2, Image Count: 364
# Folder: Raja Ampat, Image Count: 337
# Folder: Maybrat, Image Count: 355

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    #haar_image = apply_haar_wavelet(image)

                    #Resize the image to 224x224 for ResNet50
                    ##haar_image = apply_haar_wavelet_and_gaussian(haar_image)

                    # Extract HOG features
                    #hog_features = extract_hog_features(haar_image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)


                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    # 1. Gaussian Smoothing
                    gaussian_image = cv2.GaussianBlur(image, (5, 5), 0)

                    # 2. Haar Wavelet (Modified for 3 channels)
                    haar_image_LL = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,0]) #Channel R
                    haar_image_LH = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,1]) #Channel G
                    haar_image_HL = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,2]) #Channel B
                    haar_image = np.stack([haar_image_LL,haar_image_LH, haar_image_HL], axis=-1)
                    haar_image = cv2.resize(haar_image.astype(np.uint8), IMAGE_SIZE)

                    # 3. HOG Features (on the 3-channel Haar output)
                    hog_features = extract_hog_features(haar_image)

                    data.append(hog_features)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 4  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
#fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
#for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
#    axes[i].imshow(image.astype(np.uint8), cmap='gray')
#    axes[i].axis('off')
#    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
#plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
#from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 880
# Jumlah data validasi: 220
# Jumlah data test: 276

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    #base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1100
# Jumlah data validasi: 220
# Jumlah data test: 276

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - accuracy: 0.2565 - loss: 14.8051 - val_accuracy: 0.4203 - val_loss: 13.6155 - learning_rate: 1.0000e-04
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.3313 - loss: 14.1948 - val_accuracy: 0.5072 - val_loss: 13.4075 - learning_rate: 1.0000e-04
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 372ms/step - accuracy: 0.4134 - loss: 13.7307 - val_accuracy: 0.5580 - val_loss: 13.1939 - learning_rate: 1.0000e-04
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.4548 - loss: 13.4677 - val_accuracy: 0.5906 - val_loss: 12.9581 - learning_rate: 1.0000e-04
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 351ms/step - accuracy: 0.4703 - loss: 13.2564 - val_accuracy: 0.6522 - val_loss: 12.7501 - learning_rate: 1.0000e-04
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.5072 - loss: 12.9918 - val_accuracy: 0.6594 - val_loss: 12.5197 - learning_rate: 1.0000e-04
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - accuracy: 0.5830 - loss: 12.6729 - val_accuracy: 0.7246 - val_loss: 12.2985 - learning_rate: 1.0000e-04
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 347ms/step - accuracy: 0.6379 - loss: 12.3945 - val_accuracy: 0.7101 - val_loss: 12.1227 - learning_rate: 1.0000e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.6348 - loss: 12.3015 - val_accuracy: 0.7138 - val_loss: 11.9564 - learning_rate: 1.0000e-04
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.6688 - loss: 12.0821 - val_accuracy: 0.7319 - val_loss: 11.7636 - learning_rate: 1.0000e-04
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.6833 - loss: 11.8853 - val_accuracy: 0.7355 - val_loss: 11.5787 - learning_rate: 1.0000e-04
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.6720 - loss: 11.7700 - val_accuracy: 0.7210 - val_loss: 11.4366 - learning_rate: 1.0000e-04
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.6837 - loss: 11.5619 - val_accuracy: 0.7536 - val_loss: 11.2761 - learning_rate: 1.0000e-04
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.6869 - loss: 11.3995 - val_accuracy: 0.7391 - val_loss: 11.1313 - learning_rate: 1.0000e-04
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.7115 - loss: 11.2429 - val_accuracy: 0.7754 - val_loss: 10.9668 - learning_rate: 1.0000e-04
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 353ms/step - accuracy: 0.7153 - loss: 11.0331 - val_accuracy: 0.7609 - val_loss: 10.7712 - learning_rate: 1.0000e-04
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.6795 - loss: 10.9889 - val_accuracy: 0.7826 - val_loss: 10.6416 - learning_rate: 1.0000e-04
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.7009 - loss: 10.7968 - val_accuracy: 0.7899 - val_loss: 10.5143 - learning_rate: 1.0000e-04
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 347ms/step - accuracy: 0.7068 - loss: 10.6174 - val_accuracy: 0.8152 - val_loss: 10.3251 - learning_rate: 1.0000e-04
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - accuracy: 0.7285 - loss: 10.3519 - val_accuracy: 0.8007 - val_loss: 10.1587 - learning_rate: 1.0000e-04
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 358ms/step - accuracy: 0.7520 - loss: 10.1908 - val_accuracy: 0.7971 - val_loss: 9.9782 - learning_rate: 1.0000e-04
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.7401 - loss: 10.0595 - val_accuracy: 0.8261 - val_loss: 9.8259 - learning_rate: 1.0000e-04
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.7513 - loss: 9.8791 - val_accuracy: 0.8116 - val_loss: 9.6657 - learning_rate: 1.0000e-04
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.7465 - loss: 9.7021 - val_accuracy: 0.8261 - val_loss: 9.4809 - learning_rate: 1.0000e-04
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 347ms/step - accuracy: 0.7598 - loss: 9.5288 - val_accuracy: 0.8080 - val_loss: 9.3386 - learning_rate: 1.0000e-04
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 343ms/step - accuracy: 0.7756 - loss: 9.3865 - val_accuracy: 0.8043 - val_loss: 9.1875 - learning_rate: 1.0000e-04
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.7657 - loss: 9.2228 - val_accuracy: 0.8080 - val_loss: 9.0222 - learning_rate: 1.0000e-04
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.7620 - loss: 9.1038 - val_accuracy: 0.8080 - val_loss: 8.8562 - learning_rate: 1.0000e-04
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.7803 - loss: 8.8890 - val_accuracy: 0.8188 - val_loss: 8.6939 - learning_rate: 1.0000e-04
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - accuracy: 0.7887 - loss: 8.7474 - val_accuracy: 0.8152 - val_loss: 8.5368 - learning_rate: 1.0000e-04
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 341ms/step - accuracy: 0.7889 - loss: 8.5601 - val_accuracy: 0.8225 - val_loss: 8.4003 - learning_rate: 1.0000e-04
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.7895 - loss: 8.4127 - val_accuracy: 0.8261 - val_loss: 8.2036 - learning_rate: 1.0000e-04
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.8221 - loss: 8.1743 - val_accuracy: 0.8188 - val_loss: 8.0371 - learning_rate: 1.0000e-04
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - accuracy: 0.7808 - loss: 8.0745 - val_accuracy: 0.8188 - val_loss: 7.8722 - learning_rate: 1.0000e-04
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 353ms/step - accuracy: 0.8016 - loss: 7.8940 - val_accuracy: 0.8188 - val_loss: 7.7084 - learning_rate: 1.0000e-04
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 341ms/step - accuracy: 0.8032 - loss: 7.7148 - val_accuracy: 0.8043 - val_loss: 7.5853 - learning_rate: 1.0000e-04
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.7975 - loss: 7.5733 - val_accuracy: 0.8080 - val_loss: 7.4180 - learning_rate: 1.0000e-04
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.8314 - loss: 7.3956 - val_accuracy: 0.8152 - val_loss: 7.2921 - learning_rate: 1.0000e-04
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.8079 - loss: 7.2732 - val_accuracy: 0.8152 - val_loss: 7.1260 - learning_rate: 1.0000e-04
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.8273 - loss: 7.0900 - val_accuracy: 0.8116 - val_loss: 6.9577 - learning_rate: 1.0000e-04
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.8422 - loss: 6.9191 - val_accuracy: 0.8188 - val_loss: 6.8059 - learning_rate: 1.0000e-04
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.8140 - loss: 6.8005 - val_accuracy: 0.8152 - val_loss: 6.6810 - learning_rate: 1.0000e-04
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 352ms/step - accuracy: 0.8511 - loss: 6.6111 - val_accuracy: 0.8188 - val_loss: 6.5214 - learning_rate: 1.0000e-04
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 343ms/step - accuracy: 0.8434 - loss: 6.4586 - val_accuracy: 0.8007 - val_loss: 6.3997 - learning_rate: 1.0000e-04
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.8513 - loss: 6.3178 - val_accuracy: 0.8188 - val_loss: 6.2299 - learning_rate: 1.0000e-04
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.8568 - loss: 6.1485 - val_accuracy: 0.8261 - val_loss: 6.0993 - learning_rate: 1.0000e-04
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 352ms/step - accuracy: 0.8601 - loss: 6.0516 - val_accuracy: 0.8225 - val_loss: 5.9814 - learning_rate: 1.0000e-04
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.8734 - loss: 5.8550 - val_accuracy: 0.8225 - val_loss: 5.8164 - learning_rate: 1.0000e-04
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 349ms/step - accuracy: 0.8577 - loss: 5.7285 - val_accuracy: 0.8116 - val_loss: 5.7007 - learning_rate: 1.0000e-04
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.8692 - loss: 5.5987 - val_accuracy: 0.8080 - val_loss: 5.5724 - learning_rate: 1.0000e-04
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.8664 - loss: 5.4592 - val_accuracy: 0.8478 - val_loss: 5.4520 - learning_rate: 1.0000e-04
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 351ms/step - accuracy: 0.8670 - loss: 5.3105 - val_accuracy: 0.8442 - val_loss: 5.3156 - learning_rate: 1.0000e-04
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.8680 - loss: 5.1679 - val_accuracy: 0.8297 - val_loss: 5.1904 - learning_rate: 1.0000e-04
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.8712 - loss: 5.0463 - val_accuracy: 0.8587 - val_loss: 5.0563 - learning_rate: 1.0000e-04
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.8995 - loss: 4.8855 - val_accuracy: 0.8043 - val_loss: 4.9860 - learning_rate: 1.0000e-04
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.9045 - loss: 4.7530 - val_accuracy: 0.8261 - val_loss: 4.8223 - learning_rate: 1.0000e-04
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 353ms/step - accuracy: 0.8874 - loss: 4.6295 - val_accuracy: 0.8297 - val_loss: 4.6959 - learning_rate: 1.0000e-04
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - accuracy: 0.9173 - loss: 4.4549 - val_accuracy: 0.8478 - val_loss: 4.5630 - learning_rate: 1.0000e-04
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.9267 - loss: 4.3492 - val_accuracy: 0.8225 - val_loss: 4.4948 - learning_rate: 1.0000e-04
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - accuracy: 0.8964 - loss: 4.2743 - val_accuracy: 0.8478 - val_loss: 4.3465 - learning_rate: 1.0000e-04
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.9270 - loss: 4.1143 - val_accuracy: 0.8587 - val_loss: 4.2698 - learning_rate: 1.0000e-04
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.8970 - loss: 4.0417 - val_accuracy: 0.8442 - val_loss: 4.2065 - learning_rate: 1.0000e-04
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 352ms/step - accuracy: 0.9039 - loss: 3.9240 - val_accuracy: 0.8370 - val_loss: 4.0499 - learning_rate: 1.0000e-04
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.9259 - loss: 3.7812 - val_accuracy: 0.8623 - val_loss: 3.8536 - learning_rate: 1.0000e-04
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 353ms/step - accuracy: 0.9073 - loss: 3.7212 - val_accuracy: 0.8478 - val_loss: 3.7611 - learning_rate: 1.0000e-04
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.9237 - loss: 3.5725 - val_accuracy: 0.8406 - val_loss: 3.6828 - learning_rate: 1.0000e-04
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.9342 - loss: 3.4366 - val_accuracy: 0.8370 - val_loss: 3.5982 - learning_rate: 1.0000e-04
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.9406 - loss: 3.3239 - val_accuracy: 0.8333 - val_loss: 3.5267 - learning_rate: 1.0000e-04
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.9303 - loss: 3.2356 - val_accuracy: 0.8007 - val_loss: 3.5115 - learning_rate: 1.0000e-04
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 343ms/step - accuracy: 0.9236 - loss: 3.1707 - val_accuracy: 0.8442 - val_loss: 3.3111 - learning_rate: 1.0000e-04
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 352ms/step - accuracy: 0.9356 - loss: 3.0567 - val_accuracy: 0.8297 - val_loss: 3.2451 - learning_rate: 1.0000e-04
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 343ms/step - accuracy: 0.9374 - loss: 2.9336 - val_accuracy: 0.8478 - val_loss: 3.1447 - learning_rate: 1.0000e-04
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.9463 - loss: 2.8324 - val_accuracy: 0.8261 - val_loss: 3.0978 - learning_rate: 1.0000e-04
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.9423 - loss: 2.7574 - val_accuracy: 0.8225 - val_loss: 2.9949 - learning_rate: 1.0000e-04
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.9476 - loss: 2.6643 - val_accuracy: 0.8478 - val_loss: 2.8262 - learning_rate: 1.0000e-04
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 352ms/step - accuracy: 0.9519 - loss: 2.5667 - val_accuracy: 0.8478 - val_loss: 2.7842 - learning_rate: 1.0000e-04
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.9639 - loss: 2.4724 - val_accuracy: 0.8225 - val_loss: 2.8157 - learning_rate: 1.0000e-04
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.9426 - loss: 2.4065 - val_accuracy: 0.8478 - val_loss: 2.6310 - learning_rate: 1.0000e-04
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 343ms/step - accuracy: 0.9526 - loss: 2.3263 - val_accuracy: 0.8333 - val_loss: 2.6247 - learning_rate: 1.0000e-04
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.9515 - loss: 2.2726 - val_accuracy: 0.8478 - val_loss: 2.4940 - learning_rate: 1.0000e-04
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 349ms/step - accuracy: 0.9388 - loss: 2.2409 - val_accuracy: 0.8225 - val_loss: 2.4046 - learning_rate: 1.0000e-04
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.9501 - loss: 2.1256 - val_accuracy: 0.8406 - val_loss: 2.3834 - learning_rate: 1.0000e-04
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.9608 - loss: 2.0329 - val_accuracy: 0.8297 - val_loss: 2.3982 - learning_rate: 1.0000e-04
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.9465 - loss: 1.9726 - val_accuracy: 0.8406 - val_loss: 2.2820 - learning_rate: 1.0000e-04
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 349ms/step - accuracy: 0.9652 - loss: 1.9022 - val_accuracy: 0.8478 - val_loss: 2.2016 - learning_rate: 1.0000e-04
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 347ms/step - accuracy: 0.9583 - loss: 1.8369 - val_accuracy: 0.8442 - val_loss: 2.1389 - learning_rate: 1.0000e-04
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 346ms/step - accuracy: 0.9523 - loss: 1.7848 - val_accuracy: 0.8587 - val_loss: 2.0174 - learning_rate: 1.0000e-04
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.9539 - loss: 1.6994 - val_accuracy: 0.8696 - val_loss: 1.9671 - learning_rate: 1.0000e-04
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 347ms/step - accuracy: 0.9514 - loss: 1.6651 - val_accuracy: 0.8696 - val_loss: 1.9148 - learning_rate: 1.0000e-04
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.9753 - loss: 1.5800 - val_accuracy: 0.8623 - val_loss: 1.8442 - learning_rate: 1.0000e-04
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 361ms/step - accuracy: 0.9816 - loss: 1.5000 - val_accuracy: 0.8659 - val_loss: 1.7938 - learning_rate: 1.0000e-04
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.9788 - loss: 1.4415 - val_accuracy: 0.8514 - val_loss: 1.7668 - learning_rate: 1.0000e-04
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.9593 - loss: 1.4321 - val_accuracy: 0.8659 - val_loss: 1.6639 - learning_rate: 1.0000e-04
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 340ms/step - accuracy: 0.9668 - loss: 1.3775 - val_accuracy: 0.8188 - val_loss: 1.8186 - learning_rate: 1.0000e-04
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.9657 - loss: 1.3139 - val_accuracy: 0.8478 - val_loss: 1.6819 - learning_rate: 1.0000e-04
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 337ms/step - accuracy: 0.9671 - loss: 1.2602 - val_accuracy: 0.8442 - val_loss: 1.6690 - learning_rate: 1.0000e-04
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 344ms/step - accuracy: 0.9679 - loss: 1.2402 - val_accuracy: 0.8406 - val_loss: 1.6692 - learning_rate: 1.0000e-04
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.9701 - loss: 1.1613 - val_accuracy: 0.8623 - val_loss: 1.6018 - learning_rate: 1.0000e-04
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.9709 - loss: 1.1203 - val_accuracy: 0.8406 - val_loss: 1.5411 - learning_rate: 1.0000e-04
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 340ms/step - accuracy: 0.9589 - loss: 1.1465 - val_accuracy: 0.8478 - val_loss: 1.4830 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 688ms/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.83      0.59      0.69        74
#          Moi2       1.00      0.96      0.98        77
#    Raja Ampat       0.96      1.00      0.98        64
# SorongSelatan       0.63      0.85      0.73        61
#
#      accuracy                           0.85       276
#     macro avg       0.85      0.85      0.84       276
#  weighted avg       0.86      0.85      0.85       276

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

random_index = random.randint(0, len(test_images) - 1)
image = test_images[random_index]
true_label = test_labels[random_index]

prediction = model.predict(np.expand_dims(image, axis=0))[0]
predicted_class_index = np.argmax(prediction)
predicted_class_label = encoder.classes_[predicted_class_index]
confidence = prediction[predicted_class_index]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
plt.imshow(image)
plt.title(f"True Label: {true_label}\nPredicted Label: {predicted_class_label}\nConfidence: {confidence:.2f}")
plt.axis('off')
plt.show()
